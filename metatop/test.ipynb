# %%
from metatop.mechanics import isotropic_elasticity_matrix

E = 1/30
nu = 0.4

C = isotropic_elasticity_matrix(E, nu, plane='stress', output_style='mandel')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from metatop.mechanics import isotropic_elasticity_matrix
#       3 E = 1/30
#       4 nu = 0.4
#
# File ~/projects/meta_design/metatop/mechanics.py:11
#       8 from loguru import logger
#       9 from sympy.core.symbol import symbols
# ---> 11 MANDEL = jnp.diag(jnp.array([1., 1., jnp.sqrt(2)]))
#      12 INV_MANDEL = jnp.diag(jnp.array([1., 1., 1./jnp.sqrt(2)]))
#      15 @jax.jit
#      16 def ray_q(A: jnp.ndarray, X: jnp.ndarray):
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/meta_design/lib/python3.11/site-packages/jax/_src/pjit.py:304, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     302 @api_boundary
#     303 def cache_miss(*args, **kwargs):
# --> 304   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
# ...

# %%
C
